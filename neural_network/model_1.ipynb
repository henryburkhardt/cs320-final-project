# %% [markdown]
# # model_1: our MVP model
# - This is our first model, a neural network which simply keeps the snake alive. It works with 100% accuracy.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow import keras
from keras.layers import *
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
from google.colab import drive

drive.mount('/content/drive')
RunningInCOLAB = 'google.colab' in str(get_ipython())

# NOTE: this path will need to be changed if you are running this in colab!
path = "./data_collection/training_data/snake2_game_output_1.csv"
if RunningInCOLAB: path = "/content/drive/MyDrive/24Winter/cs320-w24/cs320-final-project/neural_network/data_collection/training_data/snake2_game_output_1.csv"
df_import = pd.read_csv(path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import and clean data
# - Optional use of Dummy variables to encode direction - didn't end up using in the end, so **keep this set to False**

# %%
# GLOBAL VARIABLES
USE_DUMMY_FEATURES = False

# %%
df_import = pd.read_csv(path)
df_import.head()
df = df_import
df.head()
# Out:
#    obstacleL  obstableF  obstacleR  direction_choice  game_over
# 0          0          0          0                 2          0
# 1          0          0          0                 2          0
# 2          0          0          0                 1          0
# 3          0          0          0                 1          0
# 4          0          0          0                 0          0

# %% [markdown]
# ### Selecting a smaller subset of the training set (otional):
# - I realized the model could be trained with a much smaller subset of the training set because the relationship was so simple.
# - set `df = df_sample` below to turn on this option

# %%
# selecting better training set:
df_game_over = df[df['game_over'] == 1]
df_game_not_over = df[df['game_over'] == 0]
df_game_not_over_sample = df_game_not_over.sample(n=500, random_state=42)
df_game_not_over_sample

# this df will have more equal amounts of dead/alive examples
df_sample = pd.concat([df_game_over, df_game_not_over_sample], ignore_index=True)

# %% [markdown]
# ### Encode direction as dummy variables (optional):

# %%
dummy_columns = None

# downsizing data so ratio of death/non-death is more euquak
df = df_sample

if USE_DUMMY_FEATURES:
  dummy_columns = pd.get_dummies(df['direction_choice'], prefix='direction_choice')

def dir_num_to_array(direction: int):
  t = [0,0,0]
  t[direction] = 1
  return t

# %%
# alter direction_choice so it's in [-1,0,1] instead of [0,1,2]
df['direction_choice'] = df['direction_choice'] - 1
df
# Out:
#      obstacleL  obstableF  obstacleR  direction_choice  game_over
# 0            1          0          0                -1          1
# 1            0          1          0                 0          1
# 2            0          1          0                 0          1
# 3            1          0          0                -1          1
# 4            1          0          0                -1          1
# ..         ...        ...        ...               ...        ...
# 755          0          0          0                 1          0
# 756          0          0          1                -1          0
# 757          0          0          0                 1          0
# 758          0          0          0                -1          0
# 759          0          0          0                -1          0
#
# [760 rows x 5 columns]

# %%
if USE_DUMMY_FEATURES:
  df = pd.concat([df, dummy_columns], axis=1)
  df.drop('direction_choice', inplace=True, axis=1)

# %%
X = df.drop('game_over', axis=1).to_numpy()
y = df['game_over'].to_numpy()
print(X.shape, "\n", y.shape)

X_feature_shape = X.shape[1]
X_feature_shape
# Out:
# (760, 4)
#  (760,)
# 4

# %% [markdown]
# ### Create test/train sets:

# %%
# create testing and training data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Create and train model

# %%
# init model
model = keras.Sequential()

# input layer
model.add(Input(shape=(X_feature_shape,)))
model.add(Dense(units=(5), activation='sigmoid'))
# model.add(Dense(units=(5)))
model.add(Dense(units=(1), activation='sigmoid'))

optimizer = keras.optimizers.Adam(learning_rate=1e-1)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 25
#
#  dense_1 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 31 (124.00 Byte)
# Trainable params: 31 (124.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=40, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 17/17 [==============================] - 3s 17ms/step - loss: 0.1994 - accuracy: 0.6805 - val_loss: 0.1383 - val_accuracy: 0.8553
# Epoch 2/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0961 - accuracy: 0.9004 - val_loss: 0.0548 - val_accuracy: 0.9474
# Epoch 3/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9361 - val_loss: 0.0378 - val_accuracy: 0.9649
# Epoch 4/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9549 - val_loss: 0.0297 - val_accuracy: 0.9781
# Epoch 5/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0369 - accuracy: 0.9662 - val_loss: 0.0241 - val_accuracy: 0.9781
# Epoch 6/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.9662 - val_loss: 0.0196 - val_accuracy: 0.9781
# Epoch 7/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9662 - val_loss: 0.0175 - val_accuracy: 0.9868
# Epoch 8/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9737 - val_loss: 0.0099 - val_accuracy: 0.9912
# Epoch 9/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9850 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 10/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 11/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 12/40
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 13/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 14/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 15/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 16/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 17/40
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 18/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 9.4304e-04 - val_accuracy: 1.0000
# Epoch 19/40
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 8.3642e-04 - val_accuracy: 1.0000
# Epoch 20/40
# 17/17 [==============================] - 0s 5ms/step - loss: 9.6099e-04 - accuracy: 1.0000 - val_loss: 7.6355e-04 - val_accuracy: 1.0000
# Epoch 21/40
# 17/17 [==============================] - 0s 5ms/step - loss: 8.5716e-04 - accuracy: 1.0000 - val_loss: 6.7321e-04 - val_accuracy: 1.0000
# Epoch 22/40
# 17/17 [==============================] - 0s 5ms/step - loss: 7.7667e-04 - accuracy: 1.0000 - val_loss: 6.1738e-04 - val_accuracy: 1.0000
# Epoch 23/40
# 17/17 [==============================] - 0s 6ms/step - loss: 7.0449e-04 - accuracy: 1.0000 - val_loss: 5.6527e-04 - val_accuracy: 1.0000
# Epoch 24/40
# 17/17 [==============================] - 0s 5ms/step - loss: 6.4474e-04 - accuracy: 1.0000 - val_loss: 5.1241e-04 - val_accuracy: 1.0000
# Epoch 25/40
# 17/17 [==============================] - 0s 5ms/step - loss: 5.9424e-04 - accuracy: 1.0000 - val_loss: 4.7648e-04 - val_accuracy: 1.0000
# Epoch 26/40
# 17/17 [==============================] - 0s 5ms/step - loss: 5.4904e-04 - accuracy: 1.0000 - val_loss: 4.4384e-04 - val_accuracy: 1.0000
# Epoch 27/40
# 17/17 [==============================] - 0s 5ms/step - loss: 5.0646e-04 - accuracy: 1.0000 - val_loss: 4.0798e-04 - val_accuracy: 1.0000
# Epoch 28/40
# 17/17 [==============================] - 0s 5ms/step - loss: 4.7064e-04 - accuracy: 1.0000 - val_loss: 3.8174e-04 - val_accuracy: 1.0000
# Epoch 29/40
# 17/17 [==============================] - 0s 5ms/step - loss: 4.4292e-04 - accuracy: 1.0000 - val_loss: 3.6179e-04 - val_accuracy: 1.0000
# Epoch 30/40
# 17/17 [==============================] - 0s 6ms/step - loss: 4.0953e-04 - accuracy: 1.0000 - val_loss: 3.3160e-04 - val_accuracy: 1.0000
# Epoch 31/40
# 17/17 [==============================] - 0s 6ms/step - loss: 3.8570e-04 - accuracy: 1.0000 - val_loss: 3.1228e-04 - val_accuracy: 1.0000
# Epoch 32/40
# 17/17 [==============================] - 0s 5ms/step - loss: 3.6396e-04 - accuracy: 1.0000 - val_loss: 2.9689e-04 - val_accuracy: 1.0000
# Epoch 33/40
# 17/17 [==============================] - 0s 5ms/step - loss: 3.4111e-04 - accuracy: 1.0000 - val_loss: 2.7772e-04 - val_accuracy: 1.0000
# Epoch 34/40
# 17/17 [==============================] - 0s 6ms/step - loss: 3.2190e-04 - accuracy: 1.0000 - val_loss: 2.6308e-04 - val_accuracy: 1.0000
# Epoch 35/40
# 17/17 [==============================] - 0s 5ms/step - loss: 3.0452e-04 - accuracy: 1.0000 - val_loss: 2.5033e-04 - val_accuracy: 1.0000
# Epoch 36/40
# 17/17 [==============================] - 0s 5ms/step - loss: 2.8845e-04 - accuracy: 1.0000 - val_loss: 2.3789e-04 - val_accuracy: 1.0000
# Epoch 37/40
# 17/17 [==============================] - 0s 5ms/step - loss: 2.7363e-04 - accuracy: 1.0000 - val_loss: 2.2618e-04 - val_accuracy: 1.0000
# Epoch 38/40
# 17/17 [==============================] - 0s 5ms/step - loss: 2.6047e-04 - accuracy: 1.0000 - val_loss: 2.1507e-04 - val_accuracy: 1.0000
# Epoch 39/40
# 17/17 [==============================] - 0s 5ms/step - loss: 2.4797e-04 - accuracy: 1.0000 - val_loss: 2.0503e-04 - val_accuracy: 1.0000
# Epoch 40/40
# 17/17 [==============================] - 0s 5ms/step - loss: 2.3679e-04 - accuracy: 1.0000 - val_loss: 1.9576e-04 - val_accuracy: 1.0000

# %%
# Create a figure with two subplots arranged in a single row
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))  # Adjust figsize as needed

# Plot training & validation loss values
ax1.plot(history.history['loss'])
ax1.plot(history.history['val_loss'])
ax1.set_title('Model loss')
ax1.set_ylabel('Loss')
ax1.set_xlabel('Epoch')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation accuracy values
ax2.plot(history.history['accuracy'])
ax2.plot(history.history['val_accuracy'])
ax2.set_title('Model accuracy')
ax2.set_ylabel('Accuracy')
ax2.set_xlabel('Epoch')
ax2.legend(['Train', 'Validation'], loc='upper left')

# Display the plots
plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()

# %%
model.save("/content/drive/MyDrive/24Winter/cs320-w24/cs320-final-project/models/snake2_possiblemvp_functional1.keras")

# %%
model.evaluate(X_train, y_train)
# Out:
# 17/17 [==============================] - 0s 2ms/step - loss: 2.3009e-04 - accuracy: 1.0000
# [0.0002300910564372316, 1.0]

# %% [markdown]
# ## Verifying model works on specific examples, looking at deeper stats on accuracy
# Below are a couple spot-checks I did to make sure the model was perforning exactly how I thought it would

# %%
# make the predictions binary instead of continuous
y_preds = model.predict(X_test)

y_preds[y_preds > 0.5] = 1
y_preds[y_preds <= 0.5] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # make the predictions binary instead of continous
# ----> 2 y_preds = model.predict(X_test)
#       4 y_preds[y_preds > 0.5] = 1
#       5 y_preds[y_preds <= 0.5] = 0
#
# NameError: name 'model' is not defined

# %%
# overall accuracy
y_test_reshape = y_test.reshape((y_test.shape[0], 1))

print("Overall Accuracy:")
len(y_preds[np.where(y_preds == y_test_reshape)])/len(y_preds)
# Out:
# Overall Accuracy:
# 1.0

# %%
# accuracy where game_over == 1
# used to see if the model is biasing living or non-living examples
y_preds_gameover_subset = y_preds[X_test[:,3] == 1]
y_test_subset = y_test[X_test[:,3] == 1]
y_test_subset = y_test_subset.reshape((y_test_subset.shape[0], 1))

print("Accuracy of Moves that End Game:")
len(y_preds_gameover_subset[y_preds_gameover_subset == y_test_subset])/len(y_test_subset)
# Out:
# Accuracy of Moves that End Game:
# 1.0

# %%
# here, we see that the model is accurately predicting a move to avoid and obstacle! yay!

obs = [0,0,1]
direction = -1
input = np.concatenate([obs, [direction]]).reshape((1,4))

print(input)


model.predict(input)
# Out:
# [[ 0  0  1 -1]]
# 1/1 [==============================] - 0s 30ms/step
# array([[0.00061874]], dtype=float32)

# %% [markdown]
# ## The model in action
# Want to see the model in action? Just run the play_snake_game_with_model_1.py file in the command line using `python play_snake_game_with_model_1.py `. Not that this will not work in Colab, it must be run locally to see the graphics.
